# %% [markdown]
# # COVID-19のTOKYOの状況を中心に可視化1
# > COVID-19のTOKYOの状況を中心に可視化1
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [jupyter, COVID-19]

# %% [markdown]
# ## 東京都 新型コロナウイルス陽性患者発表詳細
#
# https://catalog.data.metro.tokyo.lg.jp/dataset/t000010d0000000068

# %%
import pandas as pd
import altair as alt
import requests
import io

URL = "https://stopcovid19.metro.tokyo.lg.jp/data/130001_tokyo_covid19_patients.csv"

r = requests.get(URL)
df = pd.read_csv(io.BytesIO(r.content), sep=",")
df = df.drop(0).replace('代', '', regex=True)
df
# Out:
#         No  全国地方公共団体コード 都道府県名  市区町村名      公表_年月日 曜日  発症_年月日     居住地  年代  性別  \
# 1      1.0       130001   東京都    NaN  2020-01-24  金     NaN  湖北省武漢市  40  男性
# 2      2.0       130001   東京都    NaN  2020-01-25  土     NaN  湖北省武漢市  30  女性
# 3      3.0       130001   東京都    NaN  2020-01-30  木     NaN  湖南省長沙市  30  女性
# 4      4.0       130001   東京都    NaN  2020-02-13  木     NaN      都内  70  男性
# 5      5.0       130001   東京都    NaN  2020-02-14  金     NaN      都内  50  女性
# ..     ...          ...   ...    ...         ... ..     ...     ...  ..  ..
# 132  132.0       130001   東京都    NaN  2020-03-21  土     NaN      都内  50  男性
# 133  133.0       130001   東京都    NaN  2020-03-21  土     NaN      都内  30  男性
# 134  134.0       130001   東京都    NaN  2020-03-21  土     NaN      都内  50  男性
# 135  135.0       130001   東京都    NaN  2020-03-21  土     NaN      都内  40  男性
# 136  136.0       130001   東京都    NaN  2020-03-21  土     NaN      都内  40  男性
#
#      患者_属性  患者_状態  患者_症状  患者_渡航歴の有無フラグ  備考  退院済フラグ
# 1      NaN    NaN    NaN           NaN NaN     1.0
# 2      NaN    NaN    NaN           NaN NaN     1.0
# 3      NaN    NaN    NaN           NaN NaN     1.0
# 4      NaN    NaN    NaN           NaN NaN     NaN
# 5      NaN    NaN    NaN           NaN NaN     1.0
# ..     ...    ...    ...           ...  ..     ...
# 132    NaN    NaN    NaN           NaN NaN     NaN
# 133    NaN    NaN    NaN           NaN NaN     NaN
# 134    NaN    NaN    NaN           NaN NaN     NaN
# 135    NaN    NaN    NaN           NaN NaN     NaN
# 136    NaN    NaN    NaN           NaN NaN     NaN
#
# [136 rows x 16 columns]

# %%
alt.Chart(df).mark_line().encode(
    alt.X("公表_年月日"),
    y='count()',
)
# Out:
# alt.Chart(...)

# %%
df2 = df[['No']]
